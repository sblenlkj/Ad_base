# %% [markdown]
# ## 18
# chooose and df.corr()

# %%
import pandas as pd

a = [30.2, 25.8, 17.1, 20.0, 30.0]
b = [800, 220, 300, 300, 500]

# %%
df = pd.DataFrame(zip(a, b))
df.corr()
# Out:
#           0         1
# 0  1.000000  0.681879
# 1  0.681879  1.000000

# %%
df = pd.DataFrame([a, b]).T
df.corr()
# Out:
#           0         1
# 0  1.000000  0.681879
# 1  0.681879  1.000000

# %%
df = pd.DataFrame({"col_1": a, "col_2": b})
df.corr()
# Out:
#           col_1     col_2
# col_1  1.000000  0.681879
# col_2  0.681879  1.000000

# %% [markdown]
# ## 28 - 29
# Diagramm and True/False
# [Методические материалы](https://edu.hse.ru/tokenpluginfile.php/a7154ed45bf41e3deca6f8e33d50a571/2304532/course/section/876414/DA_method_materials.pdf)
#
# Идеи:
# - Изменение переменной Critic_Score совершенно не влияет на изменение переменной EU_Sales - **обычно неверно**.
# - Построенная диаграмма показывает, что в выборке, возможно, есть выбросы.
#
# сильная отрицательная / положительная линейная взаимосвязь - ее должно быть видно

# %%
import pandas as pd

df = pd.read_csv('c.csv')

# %%
# диаграма рассеяния 
import matplotlib.pyplot as plt
plt.scatter(df['NA_Sales'], df['EU_Sales']);

# %%
# столбиковая диаграма
df['Genre'].value_counts().plot(kind='bar');

# %%
df['Genre'].value_counts().head()
# Out:
# Genre
# Action          3370
# Sports          2348
# Misc            1750
# Role-Playing    1500
# Shooter         1323
# Name: count, dtype: int64

# %%
# гистограмма
df['Year_of_Release'].hist();
# Out:
# <Axes: >

# %%
plt.scatter(df['Global_Sales'], df['NA_Sales']);

# %% [markdown]
# ## 30

# %%
df.corr(numeric_only=True)
# Out:
#                  Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year_of_Release         1.000000 -0.092562  0.003842 -0.168386     0.037700
# NA_Sales               -0.092562  1.000000  0.765336  0.449598     0.638654
# EU_Sales                0.003842  0.765336  1.000000  0.435068     0.722796
# JP_Sales               -0.168386  0.449598  0.435068  1.000000     0.291096
# Other_Sales             0.037700  0.638654  0.722796  0.291096     1.000000
# Global_Sales           -0.076433  0.941010  0.901239  0.612300     0.749242
# Critic_Score            0.011411  0.240755  0.220752  0.152593     0.198554
# Critic_Count            0.223407  0.295413  0.277533  0.180219     0.251639
# User_Count              0.175339  0.246429  0.283360  0.075638     0.238982
#
#                  Global_Sales  Critic_Score  Critic_Count  User_Count
# Year_of_Release     -0.076433      0.011411      0.223407    0.175339
# ...

# %%
df.corr(numeric_only=True)['NA_Sales'].to_frame()
# Out:
#                  NA_Sales
# Year_of_Release -0.092562
# NA_Sales         1.000000
# EU_Sales         0.765336
# JP_Sales         0.449598
# Other_Sales      0.638654
# Global_Sales     0.941010
# Critic_Score     0.240755
# Critic_Count     0.295413
# User_Count       0.246429

# %%
corr1 = df.corr(numeric_only=True)['NA_Sales']
round(corr1.sort_values(key=lambda x: abs(x), ascending=False).iloc[1], 2)
# Out:
# 0.94
